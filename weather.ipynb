# %% [markdown]
# # WEATHER FORECASTING DATA ANALYSIS

# %% [markdown]
# # The  Weather Forecasting Dataset
# Here,The weather forecasting dataset is a time series data set with per-hour information about the weather conditions at a particular location.it records Temperature,Dew Point Temperature,Relative Humidity,Wind Speed,Visibility,Pressure and Conditions.
# The data is available as a CSV file.We are going to analyze data set using the numpy,pandas and seaborn DataFrame.

# %% [markdown]
# # Importing a dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Read a dataset Or Read the CSV file

# %%
data=pd.read_csv("G:\weather_project\weather.csv",encoding="unicode_escape");

# %% [markdown]
# # Print the dataset

# %%
data
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    01-01-2012 00:00    -1.8              -3.9         86                4
# 1    01-01-2012 01:00    -1.8              -3.7         87                4
# 2    01-01-2012 02:00    -1.8              -3.4         89                7
# 3    01-01-2012 03:00    -1.5              -3.2         88                6
# 4    01-01-2012 04:00    -1.5              -3.3         88                7
# ..                ...     ...               ...        ...              ...
# 859  03-12-2012 19:00     8.7               1.1         59               13
# 860  03-12-2012 20:00     9.2               1.4         58               13
# 861  03-12-2012 21:00     8.4               1.0         60               13
# 862  03-12-2012 22:00     7.9               0.7         60               11
# 863  03-12-2012 23:00     6.6              -0.3         61               11
#
#      Visibility_km  Press_kPa               Weather
# ...

# %% [markdown]
# # head()=It shows the first N rows in the data(by default N=5)

# %%
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
#If you want to find out first 10 values
data.head(10)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
# 5  01-01-2012 05:00    -1.4              -3.3         87                9
# 6  01-01-2012 06:00    -1.5              -3.1         89                7
# 7  01-01-2012 07:00    -1.4              -3.6         85                7
# 8  01-01-2012 08:00    -1.4              -3.6         85                9
# 9  01-01-2012 09:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %% [markdown]
# # tail()=It shows the last N records in the data(by default N=5)

# %%
data.tail()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 859  03-12-2012 19:00     8.7               1.1         59               13
# 860  03-12-2012 20:00     9.2               1.4         58               13
# 861  03-12-2012 21:00     8.4               1.0         60               13
# 862  03-12-2012 22:00     7.9               0.7         60               11
# 863  03-12-2012 23:00     6.6              -0.3         61               11
#
#      Visibility_km  Press_kPa        Weather
# 859           25.0     101.50         Cloudy
# 860           25.0     101.44         Cloudy
# 861           25.0     101.39  Mostly Cloudy
# 862           25.0     101.35  Mostly Cloudy
# 863           25.0     101.22  Mostly Cloudy

# %%
#if you want to display last 10 records in data 
data.tail(10)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 854  03-12-2012 14:00    12.3               1.4         47                6
# 855  03-12-2012 15:00    12.4               0.6         44                4
# 856  03-12-2012 16:00    11.8               1.2         48                4
# 857  03-12-2012 17:00    11.6               1.0         48                6
# 858  03-12-2012 18:00     9.0               1.1         58               13
# 859  03-12-2012 19:00     8.7               1.1         59               13
# 860  03-12-2012 20:00     9.2               1.4         58               13
# 861  03-12-2012 21:00     8.4               1.0         60               13
# 862  03-12-2012 22:00     7.9               0.7         60               11
# 863  03-12-2012 23:00     6.6              -0.3         61               11
#
#      Visibility_km  Press_kPa        Weather
# 854           48.3     101.79  Mostly Cloudy
# ...

# %% [markdown]
# # shape=It shows the total no. of rows and columns in dataset

# %%
data.shape
# Out:
# (864, 8)

# %% [markdown]
# # index=This attribute provides the index of the dataframe

# %%
data.index
# Out:
# RangeIndex(start=0, stop=864, step=1)

# %% [markdown]
# # column=It shows the name of each column

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# # dtypes=It shows the datatype of each column

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# # nunique()=It shows the total no. of unique values in each column. It can be apply on single column as well as on whole dataset.

# %%
data.nunique()
# Out:
# Date/Time           864
# Temp_C              262
# Dew Point Temp_C    257
# Rel Hum_%            55
# Wind Speed_km/h      29
# Visibility_km        22
# Press_kPa           325
# Weather              24
# dtype: int64

# %% [markdown]
# # count()=It shows the total no. of non-null values in each column.

# %%
data.count()
# Out:
# Date/Time           864
# Temp_C              864
# Dew Point Temp_C    864
# Rel Hum_%           864
# Wind Speed_km/h     864
# Visibility_km       864
# Press_kPa           864
# Weather             864
# dtype: int64

# %% [markdown]
# # info()=It provides the basic info of data.

# %%
data.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         864 non-null    object
#  1   Temp_C            864 non-null    float64
#  2   Dew Point Temp_C  864 non-null    float64
#  3   Rel Hum_%         864 non-null    int64
#  4   Wind Speed_km/h   864 non-null    int64
#  5   Visibility_km     864 non-null    float64
#  6   Press_kPa         864 non-null    float64
#  7   Weather           864 non-null    object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 54.1+ KB

# %%
#summary of data
data.describe()
# Out:
#            Temp_C  Dew Point Temp_C   Rel Hum_%  Wind Speed_km/h  \
# count  864.000000        864.000000  864.000000       864.000000
# mean    -4.763426        -10.280556   66.260417        17.086806
# std      6.474412          6.705026   12.125187         9.702796
# min    -18.600000        -25.400000   38.000000         0.000000
# 25%     -9.400000        -14.700000   56.000000         9.000000
# 50%     -5.100000         -9.500000   66.000000        17.000000
# 75%     -0.775000         -5.200000   77.000000        22.000000
# max     12.700000          7.800000   94.000000        63.000000
#
#        Visibility_km   Press_kPa
# count     864.000000  864.000000
# mean       23.975116  101.096354
# std        12.107765    0.899604
# min         0.600000   98.670000
# 25%        19.300000  100.520000
# 50%        25.000000  101.105000
# 75%        25.000000  101.802500
# max        48.300000  103.120000

# %% [markdown]
# # Q1.Find out all the unique values in 'Wind_speed' column from dataset?

# %%
data.head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.nunique()
# Out:
# Date/Time           864
# Temp_C              262
# Dew Point Temp_C    257
# Rel Hum_%            55
# Wind Speed_km/h      29
# Visibility_km        22
# Press_kPa           325
# Weather              24
# dtype: int64

# %%
#nunique shows total no of unique values in column.
data['Wind Speed_km/h'].nunique()
# Out:
# 29

# %%
#shows all the unique values in that particular column. 
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 41, 50, 57, 63, 46], dtype=int64)

# %%
data['Weather'].nunique()
# Out:
# 24

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Haze', 'Freezing Drizzle,Haze',
#        'Freezing Rain,Haze', 'Snow,Haze', 'Freezing Fog', 'Snow,Fog',
#        'Freezing Drizzle,Snow', 'Snow,Ice Pellets', 'Rain,Fog'],
#       dtype=object)

# %% [markdown]
# # Q2.Find the number of times when the 'weather is exactly clear'.

# %%
data.head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
#value counts
data.Weather.value_counts()
# Out:
# Mostly Cloudy            186
# Cloudy                   161
# Snow                     155
# Mainly Clear             146
# Clear                    132
# Snow Showers              19
# Fog                       17
# Rain                      10
# Freezing Rain              6
# Snow,Haze                  5
# Freezing Drizzle           4
# Freezing Drizzle,Fog       3
# Rain Showers               3
# Freezing Drizzle,Haze      3
# Snow,Fog                   2
# Freezing Rain,Haze         2
# Haze                       2
# Moderate Snow              2
# Rain,Fog                   1
# Rain,Snow                  1
# Freezing Drizzle,Snow      1
# Freezing Fog               1
# Freezing Rain,Fog          1
# Snow,Ice Pellets           1
# Name: Weather, dtype: int64

# %%
#filtering
#data.head(2)
#shows the record on this particular column
data[data.Weather =='Clear']
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   01-03-2012 19:00   -16.9             -24.8         50               24
# 114  01-05-2012 18:00    -7.1             -14.4         56               11
# 115  01-05-2012 19:00    -9.2             -15.4         61                7
# 116  01-05-2012 20:00    -9.8             -15.7         62                9
# 117  01-05-2012 21:00    -9.0             -14.8         63               13
# ..                ...     ...               ...        ...              ...
# 838  03-11-2012 22:00     5.2              -1.9         60                6
# 839  03-11-2012 23:00     6.1              -2.0         56                7
# 840  03-12-2012 00:00     6.0              -1.8         57               20
# 845  03-12-2012 05:00     2.3              -1.9         74                9
# 846  03-12-2012 06:00     3.1              -1.8         70               11
#
#      Visibility_km  Press_kPa Weather
# ...

# %%
#groupby it shows all the records in group
data.groupby('Weather').get_group('Clear')
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   01-03-2012 19:00   -16.9             -24.8         50               24
# 114  01-05-2012 18:00    -7.1             -14.4         56               11
# 115  01-05-2012 19:00    -9.2             -15.4         61                7
# 116  01-05-2012 20:00    -9.8             -15.7         62                9
# 117  01-05-2012 21:00    -9.0             -14.8         63               13
# ..                ...     ...               ...        ...              ...
# 838  03-11-2012 22:00     5.2              -1.9         60                6
# 839  03-11-2012 23:00     6.1              -2.0         56                7
# 840  03-12-2012 00:00     6.0              -1.8         57               20
# 845  03-12-2012 05:00     2.3              -1.9         74                9
# 846  03-12-2012 06:00     3.1              -1.8         70               11
#
#      Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# # Q3.Find the number of times when the 'wind speed was exactly 4km/h'.

# %%
data.head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data['Wind Speed_km/h']==4
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 859    False
# 860    False
# 861    False
# 862    False
# 863    False
# Name: Wind Speed_km/h, Length: 864, dtype: bool

# %%
data[data['Wind Speed_km/h']==4]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    01-01-2012 00:00    -1.8              -3.9         86                4
# 1    01-01-2012 01:00    -1.8              -3.7         87                4
# 96   01-05-2012 00:00    -8.8             -11.7         79                4
# 101  01-05-2012 05:00    -7.0              -9.5         82                4
# 146  01-07-2012 02:00    -8.1             -11.1         79                4
# 147  01-07-2012 03:00    -7.8             -10.8         79                4
# 149  01-07-2012 05:00    -6.9              -9.7         80                4
# 164  01-07-2012 20:00    -1.8              -3.7         87                4
# 166  01-07-2012 22:00    -1.5              -3.0         89                4
# 194  01-09-2012 02:00    -9.0             -14.1         66                4
# 308  02-01-2012 20:00    -3.6              -6.4         81                4
# ...

# %% [markdown]
# # Q4.Find all the null values in the data.

# %%
#find all null values
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
#find all not null values
data.notnull().sum()
# Out:
# Date/Time           864
# Temp_C              864
# Dew Point Temp_C    864
# Rel Hum_%           864
# Wind Speed_km/h     864
# Visibility_km       864
# Press_kPa           864
# Weather             864
# dtype: int64

# %% [markdown]
# # Q5.Rename the column name 'Weather' of the data to 'Weather Condition'.

# %%
data.head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.rename(columns={'Weather' :'Weather Condition'})
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    01-01-2012 00:00    -1.8              -3.9         86                4
# 1    01-01-2012 01:00    -1.8              -3.7         87                4
# 2    01-01-2012 02:00    -1.8              -3.4         89                7
# 3    01-01-2012 03:00    -1.5              -3.2         88                6
# 4    01-01-2012 04:00    -1.5              -3.3         88                7
# ..                ...     ...               ...        ...              ...
# 859  03-12-2012 19:00     8.7               1.1         59               13
# 860  03-12-2012 20:00     9.2               1.4         58               13
# 861  03-12-2012 21:00     8.4               1.0         60               13
# 862  03-12-2012 22:00     7.9               0.7         60               11
# 863  03-12-2012 23:00     6.6              -0.3         61               11
#
#      Visibility_km  Press_kPa     Weather Condition
# ...

# %% [markdown]
# # Q6.Find the mean of column 'Visibility'?

# %%
data.head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.Visibility_km.mean()
# Out:
# 23.975115740740662

# %% [markdown]
# # Q7.What is Standard Deviation of 'Pressure' in this data?

# %%
data.Press_kPa.std()
# Out:
# 0.8996040171910273

# %% [markdown]
# # Q8.What is the Variance of 'Relative Humidity' in this data?

# %%
data['Rel Hum_%'].var()
# Out:
# 147.02016946697512

# %% [markdown]
# # Q9.Find all the instances when 'Snow' was recorded.

# %%
# data.head(2)
data['Weather'].value_counts()
# Out:
# Mostly Cloudy            186
# Cloudy                   161
# Snow                     155
# Mainly Clear             146
# Clear                    132
# Snow Showers              19
# Fog                       17
# Rain                      10
# Freezing Rain              6
# Snow,Haze                  5
# Freezing Drizzle           4
# Rain Showers               3
# Freezing Drizzle,Haze      3
# Freezing Drizzle,Fog       3
# Snow,Fog                   2
# Haze                       2
# Freezing Rain,Haze         2
# Moderate Snow              2
# Rain,Fog                   1
# Snow,Ice Pellets           1
# Rain,Snow                  1
# Freezing Drizzle,Snow      1
# Freezing Fog               1
# Freezing Rain,Fog          1
# Name: Weather, dtype: int64

# %%
data[data['Weather']=='Snow']
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55   01-03-2012 07:00   -14.0             -19.5         63               19
# 84   01-04-2012 12:00   -13.7             -21.7         51               11
# 86   01-04-2012 14:00   -11.3             -19.0         53                7
# 87   01-04-2012 15:00   -10.2             -16.3         61               11
# 88   01-04-2012 16:00    -9.4             -15.5         61               13
# ..                ...     ...               ...        ...              ...
# 645  03-03-2012 21:00     2.9              -3.6         62               46
# 646  03-03-2012 22:00     2.8              -3.4         64               57
# 647  03-03-2012 23:00     2.3              -3.1         67               33
# 767  03-08-2012 23:00     0.8              -1.4         85               35
# 768  03-09-2012 00:00    -0.1              -2.0         87               28
#
#      Visibility_km  Press_kPa Weather
# ...

# %%
#string contains
data[data['Weather'].str.contains('Snow')].head(50)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41   01-02-2012 17:00    -2.1              -9.5         57               22
# 44   01-02-2012 20:00    -5.6             -13.4         54               24
# 45   01-02-2012 21:00    -5.8             -12.8         58               26
# 47   01-02-2012 23:00    -7.4             -14.1         59               17
# 48   01-03-2012 00:00    -9.0             -16.0         57               28
# 50   01-03-2012 02:00   -10.5             -15.8         65               22
# 51   01-03-2012 03:00   -11.3             -18.7         54               33
# 53   01-03-2012 05:00   -12.9             -19.1         60               22
# 54   01-03-2012 06:00   -13.3             -19.3         61               19
# 55   01-03-2012 07:00   -14.0             -19.5         63               19
# 84   01-04-2012 12:00   -13.7             -21.7         51               11
# ...

# %% [markdown]
# # Q10.Find all the instances when 'Wind speed is above 24' and 'Visibility is 25'.

# %%
data.head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km']==25)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23   01-01-2012 23:00     5.3               2.0         79               30
# 24   01-02-2012 00:00     5.2               1.5         77               35
# 25   01-02-2012 01:00     4.6               0.0         72               39
# 26   01-02-2012 02:00     3.9              -0.9         71               32
# 27   01-02-2012 03:00     3.7              -1.5         69               33
# 28   01-02-2012 04:00     2.9              -2.3         69               32
# 29   01-02-2012 05:00     2.6              -2.3         70               32
# 30   01-02-2012 06:00     2.3              -2.6         70               26
# 31   01-02-2012 07:00     2.0              -2.9         70               33
# 42   01-02-2012 18:00    -4.1             -11.4         57               28
# 45   01-02-2012 21:00    -5.8             -12.8         58               26
# ...

# %%
#Visualize the alone column
sns.catplot('Weather',kind='count',data=data)
# Out:
# C:\Users\ANJALI HINGE\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corelation=data.corr()

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(corelation, xticklabels=corelation.columns,yticklabels=corelation.columns,
            annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Pair Plot

# %%
#Pair plot use for when you want to relationship between two variables
sns.pairplot(data)

# %% [markdown]
# # Scatter plot

# %%
sns.relplot(x='Date/Time',y='Weather',hue='Temp_C',data=data)

# %% [markdown]
# # Histogram

# %%
sns.distplot(data['Temp_C'])
# Out:
# <AxesSubplot:xlabel='Temp_C', ylabel='Density'>

# %% [markdown]
# # Box Plot

# %%
sns.catplot(x='Rel Hum_%',kind='box',data=data)

# %%
sns.catplot(x='Visibility_km',kind='box',data=data)

# %% [markdown]
# # Joint Plot

# %%
sns.jointplot(x='Date/Time',y='Weather',data=data,height=10,ratio=3,color='pink')

# %%
sns.jointplot(x='Date/Time',y='Temp_C',data=data,height=10,ratio=3,color='pink')
